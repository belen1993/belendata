"Rowland": [{'maths': (4, 10)}, {'lang': (8, 7)}], 
"Miquela": [{'maths': (7, 5)}, {'lang': (2, 7)}], 
"Sapphira": [{'maths': (4, 6)}, {'lang': (5, 2)}], 
"Zorina": [{'maths': (3, 2)}, {'lang': (4, 9)}], 
"Rosemonde": [{'maths': (10, 6)}, {'lang': (9, 9)}], 
"Alisa": [{'maths': (1, 4)}, {'lang': (9, 5)}], 
"Ginger": [{'maths': (3, 4)}, {'lang': (1, 2)}], 
"Karlis": [{'maths': (9, 8)}, {'lang': (3, 1)}], 
"Robbin": [{'maths': (7, 5)}, {'lang': (10, 8)}], 
"Kimberly": [{'maths': (3, 7)}, {'lang': (8, 1)}], 
"Udale": [{'maths': (7, 1)}, {'lang': (1, 7)}], 
"Isidor": [{'maths': (8, 2)}, {'lang': (6, 3)}], 
"Farlee": [{'maths': (5, 10)}, {'lang': (9, 9)}], 
"Katleen": [{'maths': (8, 6)}, {'lang': (9, 3)}], 
"Nanine": [{'maths': (5, 7)}, {'lang': (9, 9)}], 
"Marlow": [{'maths': (2, 4)}, {'lang': (5, 2)}]
}

# %%
#ha cogido el código y lo ha metido dentro de una función. Llama a la funcioón y le asigna un nuevo nombre.
#tengo una funcion que me encapsula un proceso. Aún así la f sigue siendo compleja. 
#define una nueva función completar_asignturas_alumno (asignaturas) y hace que eso haga todo ese código.
#podría coger todo eso de ahí y llevarlo a otra función. La nueva asignatura va a ser lo que me devuelva esa función. 
#new_asignatura[nombre_asig] = new_notas_asig
#Las nuevas new_asignatura se corresponderá a completar_asignaturas_alumno

# %%
#copia_notas = dict(notas):
#Por qué hace: Crea una copia del diccionario notas y la asigna a la variable copia_notas.
#x qué es útil: Esto se hace para trabajar con una copia del diccionario original, evitando modificar los datos originales accidentalmente.
copia_notas = dict(notas)

#Qué hace: Convierte los elementos del diccionario copia_notas en una lista de tuplas (pares clave-valor) y la asigna a la variable lnotas.
#Por qué es útil: Esto facilita la iteración sobre los elementos del diccionario, permitiendo manipular y acceder a los datos de manera más sencilla.
lnotas = list(copia_notas.items())

# %%
samplenotas = dict(lnotas[:3])
#Qué hace: Crea un nuevo diccionario samplenotas que contiene solo los primeros tres elementos de lnotas.
#Por qué es útil: Esto permite trabajar con un subconjunto más pequeño de datos para pruebas o demostraciones.

notas_con_media_x_asignatura = {}
#Qué hace: Inicializa un diccionario vacío notas_con_media_x_asignatura donde se almacenarán las nuevas notas con la media calculada.
#Por qué es útil: Mantiene la inmutabilidad del diccionario original notas.

for alumno, asignaturas in samplenotas.items():
    #Qué hace: Itera sobre cada alumno y sus asignaturas en samplenotas.
    #Por qué es útil: Permite procesar las notas de cada alumno individualmente.
    

    # Variable para la lista de notas de asignatauras
    nuevas_notas_todas_asignaturas = []
    #Qué hace: Inicializa una lista vacía nuevas_notas_todas_asignaturas para almacenar las nuevas notas de todas las asignaturas de un alumno.
    #Por qué es útil: Agrupa las notas de todas las asignaturas de un alumno en una lista.

    for asignatura in asignaturas:
        #Qué hace: Itera sobre cada asignatura del alumno.
        #Por qué es útil: Permite procesar cada asignatura individualmente.
        # Variable para cada asignatura para generar (max, min, media)
        new_asinatura = {}
        #Qué hace: Inicializa un diccionario vacío new_asinatura para almacenar las nuevas notas de una asignatura específica.
        #Por qué es útil: Mantiene las notas de una asignatura organizada.
        nombre_asig = list(asignatura.keys())[0]
        #Qué hace: Obtiene el nombre de la asignatura.
        #Por qué es útil: Necesario para identificar la asignatura en el diccionario.
        notas_asig = list(asignatura.values())[0]
        #Qué hace: Obtiene las notas de la asignatura.
        #Por qué es útil: Necesario para calcular la media de las notas.



        media = round(sum(notas_asig)/2, 2)
        #Qué hace: Calcula la media de las notas y la redondea a dos decimales.
        #Por qué es útil: Proporciona una medida central de las notas de la asignatura.

        new_notas_asig = list(notas_asig[:2])
        #Qué hace: Crea una nueva lista new_notas_asig con las dos primeras notas de la asignatura.
        #Por qué es útil: Prepara la lista para añadir la media calculada.

        new_notas_asig.append( media)
        #Qué hace: Añade la media calculada a la lista new_notas_asig.
        #Por qué es útil: Completa la lista de notas con la media.


        # Generamos la entrada para una asignatura: nombre, lista de notas
        new_asinatura[nombre_asig] = new_notas_asig
        #Qué hace: Asigna la lista de notas (incluyendo la media) al nombre de la asignatura en new_asinatura.
        #Por qué es útil: Organiza las nuevas notas bajo el nombre de la asignatura.

        # añadir asignatua a la lista
        nuevas_notas_todas_asignaturas.append(new_asinatura)
        #Qué hace: Añade el diccionario new_asinatura a la lista nuevas_notas_todas_asignaturas.
        #Por qué es útil: Agrupa todas las asignaturas con sus nuevas notas para un alumno.

    # Añado el alumno con sus notas de asignatura
    notas_con_media_x_asignatura[alumno] = nuevas_notas_todas_asignaturas
    #Qué hace: Asigna la lista nuevas_notas_todas_asignaturas al nombre del alumno en notas_con_media_x_asignatura.
    #Por qué es útil: Completa el diccionario con las nuevas notas de cada alumno.


print(notas_con_media_x_asignatura)
#Qué hace: Imprime el diccionario notas_con_media_x_asignatura con las nuevas notas y medias calculadas.
#Por qué es útil: Permite ver el resultado final del procesamiento de datos.
# Out:
# {'Sosanna': [{'maths': [4, 3, 3.5]}, {'lang': [5, 5, 5.0]}], 'Rosalind': [{'maths': [8, 6, 7.0]}, {'lang': [10, 5, 7.5]}], 'Gaspar': [{'maths': [1, 6, 3.5]}, {'lang': [7, 5, 6.0]}]}

# %%
samplenotas = dict(lnotas[:3])
#Qué hace: CREAR UN SUBCONJUNTO DE DATOS, para ello crea un nuevo diccionario samplenotas que contiene solo los primeros tres elementos de lnotas.
#Por qué es útil: Permite trabajar con un subconjunto más pequeño de datos para pruebas o demostraciones.

def completar_asignaturas_alumno(asignaturas):
    # Variable para la lista de notas de asignatauras
    nuevas_notas_todas_asignaturas = []
#Qué hace: Define la función completar_asignaturas_alumno que toma una lista de asignaturas y crea una lista vacía nuevas_notas_todas_asignaturas para almacenar las nuevas notas.
#Por qué es útil: Esta función se encargará de procesar las notas de cada asignatura de un alumno.

    for asignatura in asignaturas:
        # Variable para cada asignatura para generar (max, min, media)
        new_asinatura = {}
        nombre_asig = list(asignatura.keys())[0]
        notas_asig = list(asignatura.values())[0]
#Qué hace: Itera sobre cada asignatura del alumno, inicializa un diccionario vacío new_asinatura, obtiene el nombre de la asignatura y las notas.
#Por qué es útil: Permite procesar cada asignatura individualmente y preparar los datos para calcular la media.

        media = round(sum(notas_asig)/2, 2)
#Qué hace: Calcula la media de las notas y la redondea a dos decimales.
#Por qué es útil: Proporciona una medida central de las notas de la asignatura.

        new_notas_asig = list(notas_asig[:2])
        new_notas_asig.append(media)
#Qué hace: Crea una nueva lista new_notas_asig con las dos primeras notas de la asignatura y añade la media calculada.
#Por qué es útil: Completa la lista de notas con la media.

# Generamos la entrada para una asignatura: nombre, lista de notas
        new_asinatura[nombre_asig] = new_notas_asig
#Qué hace: Asigna la lista de notas (incluyendo la media) al nombre de la asignatura en new_asinatura.
#Por qué es útil: Organiza las nuevas notas bajo el nombre de la asignatura.

# añadir asignatua a la lista
        nuevas_notas_todas_asignaturas.append(new_asinatura)
#Qué hace: Añade el diccionario new_asinatura a la lista nuevas_notas_todas_asignaturas.
#Por qué es útil: Agrupa todas las asignaturas con sus nuevas notas para un alumno.
    return nuevas_notas_todas_asignaturas
#Qué hace: Devuelve la lista nuevas_notas_todas_asignaturas.
#Por qué es útil: Permite que la función completar_notas utilice esta lista para actualizar las notas de cada alumno.

def completar_notas(notas_a_completar):
    # Creo nueva variable para las nuevas notas (trabajamos con inmutabilidad)
    notas_con_media_x_asignatura = {}
#Qué hace: Define la función completar_notas que toma un diccionario de notas y crea un diccionario vacío notas_con_media_x_asignatura.
#Por qué es útil: Esta función se encargará de procesar las notas de cada alumno y actualizar el diccionario con las nuevas notas.

    for alumno, asignaturas in notas_a_completar.items():
        nuevas_notas_todas_asignaturas = completar_asignaturas_alumno(asignaturas)
        notas_con_media_x_asignatura[alumno] = nuevas_notas_todas_asignaturas
#Qué hace: Itera sobre cada alumno y sus asignaturas, llama a la función completar_asignaturas_alumno para obtener las nuevas notas y actualiza el diccionario notas_con_media_x_asignatura.
#Por qué es útil: Permite procesar las notas de cada alumno y actualizar el diccionario con las nuevas notas.
    return notas_con_media_x_asignatura
#Qué hace: Devuelve el diccionario notas_con_media_x_asignatura.
#Por qué es útil: Permite que el código principal utilice este diccionario para ver las notas actualizadas.

nuevas_notas = completar_notas(samplenotas)
nuevas_notas
#Qué hace: Llama a la función completar_notas con el diccionario samplenotas y almacena el resultado en nuevas_notas, luego imprime nuevas_notas.
#Por qué es útil: Permite ver el resultado final del procesamiento de datos.
# Out:
# {'Sosanna': [{'maths': [4, 3, 3.5]}, {'lang': [5, 5, 5.0]}],
#  'Rosalind': [{'maths': [8, 6, 7.0]}, {'lang': [10, 5, 7.5]}],
#  'Gaspar': [{'maths': [1, 6, 3.5]}, {'lang': [7, 5, 6.0]}]}
